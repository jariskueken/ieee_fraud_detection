# %% [markdown]
# This notebook applies dataengineering techniques to the dataset in order to scale down on features but still keep information as we currently overfit on the training data

# %%
import pandas as pd
from sklearn.decomposition import PCA

# %%
train_df = pd.read_csv('../data/train_data_prepared.csv', index_col=None)
test_df = pd.read_csv('../data/test_data_prepared.csv', index_col=None)

# %% [markdown]
# Exclude the target column for now as we are currently only interested in relations between the features themself. We will use this column later on again to determine which features may only confuse the model with unneccessary low correlation to isFraud

# %%
# exclude isFraud
if 'isFraud' in train_df.columns:
    targetCol = train_df['isFraud']
    del train_df['isFraud']
print(targetCol)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 590535    0
# 590536    0
# 590537    0
# 590538    0
# 590539    0
# Name: isFraud, Length: 590540, dtype: int64

# %%
# check for matching columns
train_cols = list(train_df.columns)
test_cols = list(test_df.columns)

for col in train_cols:
    if col not in test_cols:
        print(f'column {col} in train_cols but not in test cols')

for col in test_cols:
    if col not in train_cols:
        print(f'column {col} in test_cols but not in train cols')

print(len(train_cols))
print(len(test_cols))
# Out:
# 421
# 421

# %%
# itterate over all features and calculate the correlation
corr_features: dict[str, list[str]] = {}

train_columns = list(train_df.columns)
# print(train_df['V1','V2'].corr())
# NOTE: corr(A,B) = corr(B,A)
count = 0
# takes about 2 minutes to calculated
for feature in train_columns:
    for other_feature in train_columns:
        # skip when features are equal as they always have corr 1
        if feature != other_feature:
            corr = train_df[feature].corr(train_df[other_feature])
            count += 1
            if corr >= 0.5 or corr <= -0.5:
                print(f'corr between {feature} and {other_feature} is: {corr}')
                train_columns.remove(other_feature)
                if feature not in corr_features:
                    # as soon as we write the feature to the dict once we
                    # don't need it for the other features anymore
                    train_columns.remove(feature)
                    corr_features[feature] = []
                try:
                    corr_features[feature].append(other_feature)
                except KeyError:
                    print('KeyError')
print(f'calculated {count} correlations')
print(corr_features)
# Out:
# corr between TransactionID and TransactionDT is: 0.9982802236526589
# corr between ProductCD and addr1 is: 0.7693750620050251
# corr between ProductCD and R_emaildomain is: 0.5155265743714881
# corr between ProductCD and D6 is: -0.7554728171553914
# corr between ProductCD and D9 is: -0.5676034415402995
# corr between ProductCD and D11 is: 0.5622558630725973
# corr between ProductCD and D13 is: -0.7305736201826665
# corr between ProductCD and M1 is: -0.5939891543256874
# corr between ProductCD and M3 is: -0.53181231358868
# corr between ProductCD and M6 is: -0.7387667230798127
# corr between ProductCD and V1 is: 0.5777195244787136
# corr between ProductCD and V3 is: 0.5777194616297984
# corr between ProductCD and V5 is: 0.5777193861468608
# corr between ProductCD and V7 is: 0.5777194677849946
# corr between ProductCD and V9 is: 0.5777194932249331
# corr between ProductCD and V11 is: 0.5777193379203246
# corr between ProductCD and V167 is: -0.8659401922005097
# corr between ProductCD and V169 is: -0.870930288275673
# corr between ProductCD and V171 is: -0.8708613879442703
# corr between ProductCD and V173 is: -0.8694976267788119
# corr between ProductCD and V175 is: -0.8708385458455182
# corr between ProductCD and V177 is: -0.8660984558374671
# corr between ProductCD and V179 is: -0.864696997006481
# corr between ProductCD and V181 is: -0.8693843189351455
# corr between ProductCD and V183 is: -0.8692279575275907
# corr between ProductCD and V185 is: -0.8708501550196229
# corr between ProductCD and V187 is: -0.8691744876883011
# corr between ProductCD and V189 is: -0.8709221328651804
# corr between ProductCD and V191 is: -0.8694698283484288
# corr between ProductCD and V193 is: -0.8694339575507086
# corr between ProductCD and V195 is: -0.870896678557291
# corr between ProductCD and V197 is: -0.8708954074250563
# corr between ProductCD and V199 is: -0.8694977160679906
# corr between ProductCD and V201 is: -0.8709456017685899
# corr between ProductCD and V205 is: -0.827025701178309
# corr between ProductCD and V207 is: -0.5983640476028261
# corr between ProductCD and V209 is: -0.8227416838925107
# corr between ProductCD and V214 is: -0.7197211598980265
# corr between ProductCD and V216 is: -0.6738422096139338
# corr between ProductCD and V218 is: -0.8183110488375539
# corr between ProductCD and V220 is: -0.8703977663190877
# corr between ProductCD and V222 is: -0.8704099709398833
# corr between ProductCD and V224 is: -0.818741856473189
# corr between ProductCD and V226 is: -0.8187100054382425
# corr between ProductCD and V228 is: -0.8189492368156784
# corr between ProductCD and V230 is: -0.8189552165628131
# corr between ProductCD and V232 is: -0.8185683878061154
# corr between ProductCD and V234 is: -0.8692984594137115
# corr between ProductCD and V236 is: -0.8187579945056159
# corr between ProductCD and V238 is: -0.8703420795763684
# corr between ProductCD and V240 is: -0.8188607013109923
# corr between ProductCD and V242 is: -0.8188820509618442
# corr between ProductCD and V244 is: -0.8188861866332601
# corr between ProductCD and V246 is: -0.8189037829985308
# corr between ProductCD and V248 is: -0.8188519233233706
# corr between ProductCD and V250 is: -0.8703520872830556
# corr between ProductCD and V252 is: -0.8188517953977468
# corr between ProductCD and V254 is: -0.8188390795380739
# corr between ProductCD and V256 is: -0.8703461286689324
# corr between ProductCD and V258 is: -0.818909428188877
# corr between ProductCD and V260 is: -0.818843514896671
# corr between ProductCD and V262 is: -0.8188395191725016
# corr between ProductCD and V266 is: -0.7953750661308561
# corr between ProductCD and V268 is: -0.7681810043300966
# corr between ProductCD and V270 is: -0.8673853292426046
# corr between ProductCD and V272 is: -0.8667663218416853
# corr between ProductCD and V275 is: -0.5240594516634502
# corr between ProductCD and V277 is: -0.6262527056720303
# corr between ProductCD and id_01 is: -0.8896560113029516
# corr between ProductCD and id_03 is: -0.5361724595739615
# corr between ProductCD and id_05 is: -0.865536855292245
# corr between ProductCD and id_09 is: -0.5676113741484946
# corr between ProductCD and id_11 is: -0.878742476373686
# corr between ProductCD and id_13 is: -0.8332725072945407
# corr between ProductCD and id_15 is: 0.8241400186680985
# corr between ProductCD and id_17 is: -0.8829288092323154
# corr between ProductCD and id_20 is: -0.8762615054616422
# corr between ProductCD and id_29 is: 0.808599513133107
# corr between ProductCD and id_31 is: 0.6121757912051704
# corr between ProductCD and id_35 is: 0.9224684155030756
# corr between ProductCD and id_37 is: 0.8136865112773146
# corr between ProductCD and DeviceInfo is: 0.5008836476479986
# corr between card3 and card5 is: 0.5424686159786799
# corr between addr2 and D12 is: -0.9284644657681012
# corr between addr2 and V168 is: -0.5338481782913516
# corr between addr2 and V172 is: -0.5384215977135628
# corr between addr2 and V176 is: -0.5385835275497416
# corr between addr2 and V180 is: -0.5400196262957804
# corr between addr2 and V184 is: -0.5405691245781762
# corr between addr2 and V188 is: -0.5406478180007289
# corr between addr2 and V192 is: -0.5382666696358653
# corr between addr2 and V196 is: -0.5383668362361027
# corr between addr2 and V200 is: -0.5406999916572959
# corr between addr2 and V206 is: -0.5244563119729456
# corr between addr2 and V210 is: -0.5335505014297579
# corr between addr2 and V221 is: -0.5274458034341697
# corr between addr2 and V227 is: -0.5273845451953525
# corr between addr2 and V239 is: -0.5273445993739195
# corr between addr2 and V245 is: -0.5273621389719821
# corr between addr2 and V251 is: -0.5273219722452959
# corr between addr2 and V255 is: -0.5273055566912568
# corr between addr2 and V259 is: -0.5274030535884583
# corr between addr2 and V271 is: -0.5238898675764443
# corr between addr2 and id_02 is: -0.6211782011848028
# corr between addr2 and id_06 is: -0.5470201944963516
# corr between addr2 and id_19 is: -0.5305887345724496
# corr between addr2 and id_36 is: 0.5513490271743934
# corr between C1 and C2 is: 0.995089459223489
# corr between C1 and C6 is: 0.9822377722078445
# corr between C1 and C8 is: 0.9677463528943349
# corr between C1 and C10 is: 0.9582021807775146
# corr between C1 and C12 is: 0.9279394882293623
# corr between C1 and C14 is: 0.9517609999340406
# corr between C4 and C7 is: 0.895092400866198
# corr between C4 and C13 is: 0.644549338891172
# corr between C9 and C5 is: 0.9257858192208457
# corr between D2 and D1 is: 0.6812712172907162
# corr between D5 and D3 is: 0.5181028834741038
# corr between D5 and V35 is: 0.5980362493008424
# corr between D5 and V37 is: 0.5981782307452705
# corr between D5 and V39 is: 0.5980146841449875
# corr between D5 and V41 is: 0.5980723912732591
# corr between D5 and V43 is: 0.5980186674470745
# corr between D5 and V45 is: 0.5981910562749038
# corr between D5 and V47 is: 0.5981113643616781
# corr between D5 and V49 is: 0.5981788496313779
# corr between D5 and V51 is: 0.5980023875708518
# corr between D14 and V170 is: 0.6065561712462475
# corr between D14 and V182 is: 0.6057118818701094
# corr between D14 and V190 is: 0.6054755324385983
# corr between D14 and V198 is: 0.6064032222804756
# corr between D14 and V208 is: 0.605963519348487
# corr between D14 and V217 is: 0.6161067923917722
# corr between D14 and V223 is: 0.6155741267866586
# corr between D14 and V229 is: 0.6157654546933664
# corr between D14 and V233 is: 0.6161494555889032
# corr between D14 and V237 is: 0.6155879647110304
# corr between D14 and V243 is: 0.6155861415517694
# corr between D14 and V249 is: 0.6155273533550469
# corr between D14 and V257 is: 0.6156594845255752
# corr between D14 and V269 is: 0.597497154933231
# corr between D14 and V276 is: 0.5031196254448468
# corr between D14 and id_12 is: -0.5199866584677265
# corr between D14 and id_16 is: -0.5198704557510945
# corr between D14 and id_38 is: -0.6331957337949738
# corr between M2 and dist1 is: -0.6511696350005579
# corr between M2 and M7 is: 0.7022026148505317
# corr between M2 and M9 is: 0.7099421101346397
# corr between M2 and V4 is: -0.8978775170624111
# corr between M2 and V8 is: -0.8978757052619211
# corr between M2 and V174 is: 0.5591477119662873
# corr between M2 and V186 is: 0.5586546791207415
# corr between M2 and V219 is: 0.5344596345365863
# corr between M2 and V231 is: 0.5344823068918394
# corr between M2 and V241 is: 0.5345093478193023
# corr between M2 and V253 is: 0.5345048730076101
# corr between M2 and id_28 is: -0.5271300982484644
# corr between M8 and V2 is: -0.6988022051154624
# corr between V10 and V6 is: 0.9999996623300597
# corr between V10 and V178 is: -0.5856332923481734
# corr between V10 and V225 is: -0.5620678354913341
# corr between V10 and V247 is: -0.5620684088614327
# corr between V14 and D4 is: 0.5301555572053318
# corr between V14 and D10 is: 0.9102882680034702
# corr between V14 and V12 is: 0.9999989876812481
# corr between V14 and V15 is: 0.9999995688726757
# corr between V14 and V17 is: 0.999999482128532
# corr between V14 and V19 is: 0.9999992982040662
# corr between V14 and V21 is: 0.9999995515770355
# corr between V14 and V23 is: 0.9999997639844473
# corr between V14 and V25 is: 0.9999998686547006
# corr between V14 and V27 is: 0.9999999948848035
# corr between V14 and V29 is: 0.9999989861950489
# corr between V14 and V31 is: 0.999999506423071
# corr between V14 and V33 is: 0.9999995467157579
# corr between V14 and V36 is: 0.5538245165166209
# corr between V14 and V40 is: 0.5537521640345462
# corr between V14 and V44 is: 0.5537915256048236
# corr between V14 and V48 is: 0.5538146672332721
# corr between V14 and V52 is: 0.5537789851284005
# corr between V14 and V54 is: 0.9121348335216436
# corr between V14 and V56 is: 0.9120795019811864
# corr between V14 and V58 is: 0.9120620384731748
# corr between V14 and V60 is: 0.9120384116830706
# corr between V14 and V62 is: 0.9120979632271956
# corr between V14 and V64 is: 0.9120392151029919
# corr between V14 and V66 is: 0.9121026090090364
# corr between V14 and V68 is: 0.9120876188726379
# corr between V14 and V70 is: 0.9121189363827659
# corr between V14 and V72 is: 0.9120388367515394
# corr between V14 and V74 is: 0.9120617046138239
# corr between V14 and V76 is: 0.8339334345433156
# corr between V14 and V78 is: 0.8338858472664226
# corr between V14 and V80 is: 0.8338291878488917
# corr between V14 and V82 is: 0.8338906704157799
# corr between V14 and V84 is: 0.8338314999977452
# corr between V14 and V86 is: 0.8338847390387611
# corr between V14 and V88 is: 0.8338925721249126
# corr between V14 and V90 is: 0.8339196846486112
# corr between V14 and V92 is: 0.8338308617644258
# corr between V14 and V94 is: 0.8338713299371707
# corr between V14 and V138 is: -0.8985424973469718
# corr between V14 and V140 is: -0.8985886282297222
# corr between V14 and V142 is: -0.8985353068263707
# corr between V14 and V144 is: -0.8985854863736907
# corr between V14 and V146 is: -0.8985480705863367
# corr between V14 and V148 is: -0.8985815454337756
# corr between V14 and V150 is: -0.7499048935962092
# corr between V14 and V152 is: -0.8989441183758717
# corr between V14 and V154 is: -0.8985805377298707
# corr between V14 and V156 is: -0.8985826151886009
# corr between V14 and V158 is: -0.8985845284944571
# corr between V14 and V161 is: -0.8967104744154554
# corr between V14 and V163 is: -0.8961699068009374
# corr between V14 and V166 is: -0.6376243077002404
# corr between V14 and V235 is: -0.6718280974522771
# corr between V14 and V267 is: -0.5497157762530943
# corr between V14 and V278 is: -0.5484269006965685
# corr between V14 and V322 is: -0.8927590420067051
# corr between V14 and V324 is: -0.8886581607106024
# corr between V14 and V326 is: -0.8999391965123337
# corr between V14 and V328 is: -0.9003299336063064
# corr between V14 and V330 is: -0.8998803686457546
# corr between V14 and V334 is: -0.8675427937917769
# corr between V14 and V336 is: -0.8466613643704743
# corr between V14 and V338 is: -0.5550344546654539
# corr between V14 and id_14 is: -0.8414215919171129
# corr between V14 and id_32 is: -0.8696946055532624
# corr between V14 and id_34 is: 0.8231182167851931
# corr between V24 and D15 is: 0.7628363934236626
# corr between V24 and V13 is: 0.9999986027479917
# corr between V24 and V18 is: 0.9999992213450368
# corr between V24 and V22 is: 0.9999991939710271
# corr between V24 and V28 is: 0.9999996341802816
# corr between V24 and V32 is: 0.999999186971218
# corr between V24 and V38 is: 0.5538042441520725
# corr between V24 and V46 is: 0.553807336748372
# corr between V24 and V53 is: 0.912125764722969
# corr between V24 and V57 is: 0.9120566711304317
# corr between V24 and V61 is: 0.9120902370402977
# corr between V24 and V65 is: 0.9120837945234506
# corr between V24 and V69 is: 0.9121118590876961
# corr between V24 and V73 is: 0.9120564991214352
# corr between V24 and V77 is: 0.8338902007252038
# corr between V24 and V81 is: 0.8338289502265893
# corr between V24 and V85 is: 0.8338284124156391
# corr between V24 and V89 is: 0.8338910923944016
# corr between V24 and V93 is: 0.8338314895836205
# corr between V24 and V139 is: -0.898589938991868
# corr between V24 and V143 is: -0.8912754160234594
# corr between V24 and V147 is: -0.8985482765389295
# corr between V24 and V151 is: -0.8988726665723462
# corr between V24 and V155 is: -0.8985807965648117
# corr between V24 and V162 is: -0.8955217721973425
# corr between V24 and V194 is: -0.6533895177281619
# corr between V24 and V261 is: -0.6718062055234265
# corr between V24 and V323 is: -0.8819365520494552
# corr between V24 and V327 is: -0.9003253070335328
# corr between V24 and V335 is: -0.7984766772042041
# corr between V24 and V339 is: -0.6532706961605002
# corr between V24 and id_30 is: 0.7497857480600554
# corr between V55 and V16 is: 0.912071853091004
# corr between V55 and V26 is: 0.9120795349081524
# corr between V55 and V34 is: 0.9120734225445508
# corr between V55 and V50 is: 0.55987372875974
# corr between V55 and V63 is: 0.9999992450835739
# corr between V55 and V71 is: 0.9999992155215408
# corr between V55 and V79 is: 0.8314268815928666
# corr between V55 and V87 is: 0.8314255479403426
# corr between V55 and V141 is: -0.9388096620951059
# corr between V55 and V149 is: -0.9388448442386697
# corr between V55 and V157 is: -0.9388475544477597
# corr between V55 and V325 is: -0.941286330665596
# corr between V55 and V337 is: -0.7584000911997623
# corr between V55 and id_33 is: 0.8121839833980637
# corr between V95 and V96 is: 0.9180882896900179
# corr between V95 and V99 is: 0.7623502936069823
# corr between V95 and V101 is: 0.9997604205570887
# corr between V95 and V103 is: 0.9654760663844008
# corr between V95 and V105 is: 0.8123827161090612
# corr between V95 and V107 is: 0.7388106818831334
# corr between V95 and V109 is: 0.7387984558460925
# corr between V95 and V111 is: 0.7388142491780515
# corr between V95 and V113 is: 0.73881313814539
# corr between V95 and V115 is: 0.7387815563434592
# corr between V95 and V117 is: 0.7388116406268328
# corr between V95 and V119 is: 0.7388112005232108
# corr between V95 and V121 is: 0.7388063832071015
# corr between V95 and V123 is: 0.7391293992430594
# corr between V95 and V125 is: 0.7406733546485876
# corr between V95 and V127 is: 0.6343261322827994
# corr between V95 and V132 is: 0.6789635911073488
# corr between V95 and V134 is: 0.6411778293490551
# corr between V95 and V164 is: 0.6589317181913789
# corr between V95 and V202 is: 0.6483432086532115
# corr between V95 and V204 is: 0.5975964066265124
# corr between V95 and V212 is: 0.6176230683585843
# corr between V95 and V279 is: 0.6587278651821202
# corr between V95 and V293 is: 0.6579447766428036
# corr between V95 and V295 is: 0.618152609090634
# corr between V95 and V306 is: 0.6608088453030913
# corr between V95 and V308 is: 0.6215765687886864
# corr between V95 and V316 is: 0.6697302936264998
# corr between V95 and V318 is: 0.6297939802388562
# corr between V95 and V331 is: 0.6584916488910457
# corr between V95 and V333 is: 0.6251949201870144
# corr between V98 and V97 is: 0.6409852308646368
# corr between V98 and V102 is: 0.5411499426598126
# corr between V98 and V106 is: 0.9969436199024263
# corr between V98 and V110 is: 0.999915959355401
# corr between V98 and V114 is: 0.9999144974158718
# corr between V98 and V118 is: 0.9999220728338486
# corr between V98 and V122 is: 0.9999218943969269
# corr between V108 and V100 is: 0.9991514924319232
# corr between V108 and V112 is: 0.9999938923147781
# corr between V108 and V120 is: 0.9999941837200126
# corr between V126 and V128 is: 0.9401304682013681
# corr between V126 and V133 is: 0.9381254535759648
# corr between V126 and V136 is: 0.7076761813631125
# corr between V126 and V165 is: 0.7947564135726195
# corr between V126 and V211 is: 0.9550611101613978
# corr between V126 and V280 is: 0.8989355834919566
# corr between V126 and V294 is: 0.8426709332913368
# corr between V126 and V307 is: 0.8991226166666743
# corr between V126 and V317 is: 0.8947426678415993
# corr between V126 and V320 is: 0.6111397586230628
# corr between V126 and V332 is: 0.9359347371970752
# corr between V130 and V131 is: 0.7505092365600982
# corr between V130 and V310 is: 0.8388389866103655
# corr between V130 and V312 is: 0.648057629465121
# corr between V137 and V135 is: 0.9137505289125765
# corr between V137 and V319 is: 0.6847201534596684
# corr between V159 and V160 is: 0.8801235644518017
# corr between V213 and V203 is: 0.9164239275029226
# corr between V213 and V298 is: 0.5024750726914736
# corr between V264 and V263 is: 0.7446206577471526
# corr between V264 and V273 is: 0.666304897695666
# corr between V281 and V282 is: 0.9998810188739515
# corr between V281 and V288 is: 0.9999448010855055
# corr between V281 and V296 is: 0.9974636477161363
# corr between V281 and V300 is: 0.9999249247361607
# corr between V284 and V285 is: 0.8219794312431441
# corr between V284 and V290 is: 0.9852501548209066
# corr between V284 and V292 is: 0.766365281964561
# corr between V284 and V299 is: 0.934499734932346
# corr between V284 and V302 is: 0.9918013926547672
# corr between V284 and V304 is: 0.9908176806347867
# corr between V287 and V286 is: 0.9733152563017555
# corr between V287 and V297 is: 0.972926168726858
# corr between V287 and V303 is: 0.966280232082797
# corr between V301 and V283 is: 0.9994813847135651
# corr between V311 and V129 is: 0.8503154340247723
# corr between V311 and V309 is: 0.8831174934143294
# corr between V329 and D8 is: 0.5279704832158101
# corr between V329 and V20 is: -0.8993636418366103
# corr between V329 and V42 is: -0.5688170651170108
# corr between V329 and V67 is: -0.9400746717305583
# corr between V329 and V83 is: -0.8246837987696627
# corr between V329 and V145 is: 0.9948603243682604
# corr between V329 and V215 is: 0.5367104671297277
# corr between V329 and id_10 is: 0.5152514294173891
# calculated 6278 correlations
# {'TransactionID': ['TransactionDT'], 'ProductCD': ['addr1', 'R_emaildomain', 'D6', 'D9', 'D11', 'D13', 'M1', 'M3', 'M6', 'V1', 'V3', 'V5', 'V7', 'V9', 'V11', 'V167', 'V169', 'V171', 'V173', 'V175', 'V177', 'V179', 'V181', 'V183', 'V185', 'V187', 'V189', 'V191', 'V193', 'V195', 'V197', 'V199', 'V201', 'V205', 'V207', 'V209', 'V214', 'V216', 'V218', 'V220', 'V222', 'V224', 'V226', 'V228', 'V230', 'V232', 'V234', 'V236', 'V238', 'V240', 'V242', 'V244', 'V246', 'V248', 'V250', 'V252', 'V254', 'V256', 'V258', 'V260', 'V262', 'V266', 'V268', 'V270', 'V272', 'V275', 'V277', 'id_01', 'id_03', 'id_05', 'id_09', 'id_11', 'id_13', 'id_15', 'id_17', 'id_20', 'id_29', 'id_31', 'id_35', 'id_37', 'DeviceInfo'], 'card3': ['card5'], 'addr2': ['D12', 'V168', 'V172', 'V176', 'V180', 'V184', 'V188', 'V192', 'V196', 'V200', 'V206', 'V210', 'V221', 'V227', 'V239', 'V245', 'V251', 'V255', 'V259', 'V271', 'id_02', 'id_06', 'id_19', 'id_36'], 'C1': ['C2', 'C6', 'C8', 'C10', 'C12', 'C14'], 'C4': ['C7', 'C13'], 'C9': ['C5'], 'D2': ['D1'], 'D5': ['D3', 'V35', 'V37', 'V39', 'V41', 'V43', 'V45', 'V47', 'V49', 'V51'], 'D14': ['V170', 'V182', 'V190', 'V198', 'V208', 'V217', 'V223', 'V229', 'V233', 'V237', 'V243', 'V249', 'V257', 'V269', 'V276', 'id_12', 'id_16', 'id_38'], 'M2': ['dist1', 'M7', 'M9', 'V4', 'V8', 'V174', 'V186', 'V219', 'V231', 'V241', 'V253', 'id_28'], 'M8': ['V2'], 'V10': ['V6', 'V178', 'V225', 'V247'], 'V14': ['D4', 'D10', 'V12', 'V15', 'V17', 'V19', 'V21', 'V23', 'V25', 'V27', 'V29', 'V31', 'V33', 'V36', 'V40', 'V44', 'V48', 'V52', 'V54', 'V56', 'V58', 'V60', 'V62', 'V64', 'V66', 'V68', 'V70', 'V72', 'V74', 'V76', 'V78', 'V80', 'V82', 'V84', 'V86', 'V88', 'V90', 'V92', 'V94', 'V138', 'V140', 'V142', 'V144', 'V146', 'V148', 'V150', 'V152', 'V154', 'V156', 'V158', 'V161', 'V163', 'V166', 'V235', 'V267', 'V278', 'V322', 'V324', 'V326', 'V328', 'V330', 'V334', 'V336', 'V338', 'id_14', 'id_32', 'id_34'], 'V24': ['D15', 'V13', 'V18', 'V22', 'V28', 'V32', 'V38', 'V46', 'V53', 'V57', 'V61', 'V65', 'V69', 'V73', 'V77', 'V81', 'V85', 'V89', 'V93', 'V139', 'V143', 'V147', 'V151', 'V155', 'V162', 'V194', 'V261', 'V323', 'V327', 'V335', 'V339', 'id_30'], 'V55': ['V16', 'V26', 'V34', 'V50', 'V63', 'V71', 'V79', 'V87', 'V141', 'V149', 'V157', 'V325', 'V337', 'id_33'], 'V95': ['V96', 'V99', 'V101', 'V103', 'V105', 'V107', 'V109', 'V111', 'V113', 'V115', 'V117', 'V119', 'V121', 'V123', 'V125', 'V127', 'V132', 'V134', 'V164', 'V202', 'V204', 'V212', 'V279', 'V293', 'V295', 'V306', 'V308', 'V316', 'V318', 'V331', 'V333'], 'V98': ['V97', 'V102', 'V106', 'V110', 'V114', 'V118', 'V122'], 'V108': ['V100', 'V112', 'V120'], 'V126': ['V128', 'V133', 'V136', 'V165', 'V211', 'V280', 'V294', 'V307', 'V317', 'V320', 'V332'], 'V130': ['V131', 'V310', 'V312'], 'V137': ['V135', 'V319'], 'V159': ['V160'], 'V213': ['V203', 'V298'], 'V264': ['V263', 'V273'], 'V281': ['V282', 'V288', 'V296', 'V300'], 'V284': ['V285', 'V290', 'V292', 'V299', 'V302', 'V304'], 'V287': ['V286', 'V297', 'V303'], 'V301': ['V283'], 'V311': ['V129', 'V309'], 'V329': ['D8', 'V20', 'V42', 'V67', 'V83', 'V145', 'V215', 'id_10']}

# %% [markdown]
# Now a new dataset is constructed of the following shape:
# - the remaining columns from the original dataset, that are not correlated to anything from dataset
# - for each set of correlated columns we run pca as follows:
#     - we run PCA on min(len(corr_features), 3)
#     - we then select only those columns from the three that push us over 90% explained variance, so if the first pc already has 97% explained variance we only take this one, if it has 85 and the second has 5 we take the first two, if we have 85, 4, 2 we take all (if this case even exists)

# %%
# construct a set of new columns, consisting of the remaining columns from before
# set to prevent olumn doubling
new_columns = set(train_columns)

train_df_new = pd.DataFrame()
test_df_new = pd.DataFrame()

# now run pca for each of the correlated columns sets
for column in corr_features:
    # join the key + all its corr features
    corr_cols = [column] + corr_features[column]
    pca_train = PCA(n_components=min(len(corr_cols), 3))
    pca_test = PCA(n_components=min(len(corr_cols), 3))

    print(f'calculating principal components for {corr_cols}')
    # calculate the principal components
    principal_components_train = pca_train.fit_transform(train_df[corr_cols])
    principal_components_test = pca_test.fit_transform(test_df[corr_cols])
    # count the explained variance ratio and the indices for the pcs (range 1,2,3)
    ratio_cnt = 0
    idx = []
    for i in range(len(pca_train.explained_variance_ratio_)):
        # by appending first we allow to stop on the step that pushed us above 90%
        # we require at least 90% cumulated variance ratio
        if ratio_cnt < 0.9:
            idx.append(i)
        else:
            # if we are above 90% we break
            break
        ratio_cnt += pca_train.explained_variance_ratio_[i]

    print(f'princial components to explain {corr_cols} have a cumulated {ratio_cnt} explained\
 variance ratio, to get above {ratio_cnt} we need pcs {idx}')

    if ratio_cnt < 0.9:
        # for those columns that have less than 90 % explained variance ratio in
        # pca with 3 components we just add the original columns
        new_columns.union(set(corr_cols)) # set to prevent doubling
        # do not continue for those column sets
        continue

    print(principal_components_train.T)
    # build the new columns and add to the dataframe
    for i in idx:
        # transpose the pcs to add the entire column
        identifier = f'{column}_set_pc{i+1}'
        print(f'adding col {identifier} to new training set')
        train_df_new[identifier] = principal_components_train.T[i]
        print(f'adding col {identifier} to new test set')
        test_df_new[identifier] = principal_components_test.T[i]

# add the remaining original columns to the new datasets
train_df_new[list(new_columns)] = train_df[list(new_columns)]
test_df_new[list(new_columns)] = test_df[list(new_columns)]

# also add the target value to the train dataframe
train_df_new['isFraud'] = targetCol
# Out:
# calculating principal components for ['TransactionID', 'TransactionDT']
# princial components to explain ['TransactionID', 'TransactionDT'] have a cumulated 0.9999953279933507 explained variance ratio, to get above 0.9999953279933507 we need pcs [0]
# [[-7291843.00769379 -7291841.97153549 -7291773.98084503 ...
#    8443917.02286219  8443926.05358815  8443969.06124281]
#  [   26706.69787834    26705.73539012    26707.24071708 ...
#      15758.5342535     15757.86642965    15758.45092999]]
# adding col TransactionID_set_pc1 to new training set
# adding col TransactionID_set_pc1 to new test set
# calculating principal components for ['ProductCD', 'addr1', 'R_emaildomain', 'D6', 'D9', 'D11', 'D13', 'M1', 'M3', 'M6', 'V1', 'V3', 'V5', 'V7', 'V9', 'V11', 'V167', 'V169', 'V171', 'V173', 'V175', 'V177', 'V179', 'V181', 'V183', 'V185', 'V187', 'V189', 'V191', 'V193', 'V195', 'V197', 'V199', 'V201', 'V205', 'V207', 'V209', 'V214', 'V216', 'V218', 'V220', 'V222', 'V224', 'V226', 'V228', 'V230', 'V232', 'V234', 'V236', 'V238', 'V240', 'V242', 'V244', 'V246', 'V248', 'V250', 'V252', 'V254', 'V256', 'V258', 'V260', 'V262', 'V266', 'V268', 'V270', 'V272', 'V275', 'V277', 'id_01', 'id_03', 'id_05', 'id_09', 'id_11', 'id_13', 'id_15', 'id_17', 'id_20', 'id_29', 'id_31', 'id_35', 'id_37', 'DeviceInfo']
# princial components to explain ['ProductCD', 'addr1', 'R_emaildomain', 'D6', 'D9', 'D11', 'D13', 'M1', 'M3', 'M6', 'V1', 'V3', 'V5', 'V7', 'V9', 'V11', 'V167', 'V169', 'V171', 'V173', 'V175', 'V177', 'V179', 'V181', 'V183', 'V185', 'V187', 'V189', 'V191', 'V193', 'V195', 'V197', 'V199', 'V201', 'V205', 'V207', 'V209', 'V214', 'V216', 'V218', 'V220', 'V222', 'V224', 'V226', 'V228', 'V230', 'V232', 'V234', 'V236', 'V238', 'V240', 'V242', 'V244', 'V246', 'V248', 'V250', 'V252', 'V254', 'V256', 'V258', 'V260', 'V262', 'V266', 'V268', 'V270', 'V272', 'V275', 'V277', 'id_01', 'id_03', 'id_05', 'id_09', 'id_11', 'id_13', 'id_15', 'id_17', 'id_20', 'id_29', 'id_31', 'id_35', 'id_37', 'DeviceInfo'] have a cumulated 0.9091257487221138 explained variance ratio, to get above 0.9091257487221138 we need pcs [0, 1, 2]
# [[-2083.89831921 -1390.27343546 -2118.45935844 ... -2077.18170603
#   -2089.59711741 -2081.52657179]
#  [  701.21597026 -1845.06884656   826.28116404 ...   694.61500609
#     706.64760957   695.89775175]
#  [   -6.30881132   149.21678365   -10.63270601 ...   -24.87452201
#       9.6197765     -9.59421418]]
# adding col ProductCD_set_pc1 to new training set
# adding col ProductCD_set_pc1 to new test set
# adding col ProductCD_set_pc2 to new training set
# adding col ProductCD_set_pc2 to new test set
# adding col ProductCD_set_pc3 to new training set
# adding col ProductCD_set_pc3 to new test set
# calculating principal components for ['card3', 'card5']
# princial components to explain ['card3', 'card5'] have a cumulated 1.0 explained variance ratio, to get above 1.0 we need pcs [0, 1]
# [[ 45.65551603  83.16316783  23.15092495 ... -31.23517016 -31.23517016
#    83.16316783]
#  [-16.76716454 -30.6659435   -8.42789717 ...  11.72533232  11.72533232
#   -30.6659435 ]]
# adding col card3_set_pc1 to new training set
# adding col card3_set_pc1 to new test set
# adding col card3_set_pc2 to new training set
# adding col card3_set_pc2 to new test set
# calculating principal components for ['addr2', 'D12', 'V168', 'V172', 'V176', 'V180', 'V184', 'V188', 'V192', 'V196', 'V200', 'V206', 'V210', 'V221', 'V227', 'V239', 'V245', 'V251', 'V255', 'V259', 'V271', 'id_02', 'id_06', 'id_19', 'id_36']
# princial components to explain ['addr2', 'D12', 'V168', 'V172', 'V176', 'V180', 'V184', 'V188', 'V192', 'V196', 'V200', 'V206', 'V210', 'V221', 'V227', 'V239', 'V245', 'V251', 'V255', 'V259', 'V271', 'id_02', 'id_06', 'id_19', 'id_36'] have a cumulated 0.9998046239192983 explained variance ratio, to get above 0.9998046239192983 we need pcs [0]
# [[-4.19274754e+04 -4.19274754e+04 -4.19274754e+04 ... -4.19274754e+04
#   -4.19274754e+04 -4.19274754e+04]
#  [-5.87140660e+02 -5.87140660e+02 -5.87140660e+02 ... -5.87140660e+02
#   -5.87140660e+02 -5.87140660e+02]
#  [ 2.17991891e+01  2.17991891e+01  2.17991890e+01 ...  2.17991890e+01
#    2.17991890e+01  2.17991890e+01]]
# adding col addr2_set_pc1 to new training set
# adding col addr2_set_pc1 to new test set
# calculating principal components for ['C1', 'C2', 'C6', 'C8', 'C10', 'C12', 'C14']
# princial components to explain ['C1', 'C2', 'C6', 'C8', 'C10', 'C12', 'C14'] have a cumulated 0.9709095300631049 explained variance ratio, to get above 0.9709095300631049 we need pcs [0]
# [[-22.7699044  -22.7699044  -22.7699044  ... -22.7699044  -21.95001645
#   -22.27805617]
#  [ -6.61540227  -6.61540227  -6.61540227 ...  -6.61540227  -6.37500313
#    -6.32465545]
#  [ -0.60838984  -0.60838984  -0.60838984 ...  -0.60838984  -1.05229484
#    -0.21460738]]
# adding col C1_set_pc1 to new training set
# adding col C1_set_pc1 to new test set
# calculating principal components for ['C4', 'C7', 'C13']
# princial components to explain ['C4', 'C7', 'C13'] have a cumulated 0.9824871869092069 explained variance ratio, to get above 0.9824871869092069 we need pcs [0, 1]
# [[-29.73382351 -29.73382351 -29.73382351 ... -29.73382351 -26.27966472
#   -29.73382351]
#  [ 11.63055193  11.63055193  11.63055193 ...  11.63055193   9.61345865
#    11.63055193]
#  [ -0.5061757   -0.5061757   -0.5061757  ...  -0.5061757   -0.51720975
#    -0.5061757 ]]
# adding col C4_set_pc1 to new training set
# adding col C4_set_pc1 to new test set
# adding col C4_set_pc2 to new training set
# adding col C4_set_pc2 to new test set
# calculating principal components for ['C9', 'C5']
# princial components to explain ['C9', 'C5'] have a cumulated 0.9693449830472101 explained variance ratio, to get above 0.9693449830472101 we need pcs [0]
# [[-6.56916595e+00 -7.09968807e+00 -6.56916595e+00 ... -5.72149486e+00
#   -6.03864382e+00 -5.19097273e+00]
#  [ 5.71890766e-03 -8.41952182e-01  5.71890766e-03 ... -5.24803217e-01
#    8.53389997e-01  3.22867873e-01]]
# adding col C9_set_pc1 to new training set
# adding col C9_set_pc1 to new test set
# calculating principal components for ['D2', 'D1']
# princial components to explain ['D2', 'D1'] have a cumulated 0.9632145741721132 explained variance ratio, to get above 0.9632145741721132 we need pcs [0]
# [[-616.46329894 -619.16118238 -619.16118238 ... -619.16118238
#    386.94128415 -619.16118238]
#  [ -41.57736042  -27.83976875  -27.83976875 ...  -27.83976875
#    147.32537284  -27.83976875]]
# adding col D2_set_pc1 to new training set
# adding col D2_set_pc1 to new test set
# calculating principal components for ['D5', 'D3', 'V35', 'V37', 'V39', 'V41', 'V43', 'V45', 'V47', 'V49', 'V51']
# princial components to explain ['D5', 'D3', 'V35', 'V37', 'V39', 'V41', 'V43', 'V45', 'V47', 'V49', 'V51'] have a cumulated 0.9597669177009824 explained variance ratio, to get above 0.9597669177009824 we need pcs [0, 1]
# [[2147.78359593 -651.32816066 -651.64944855 ... -651.97069525
#   -991.72991179 -992.69392447]
#  [ 560.88624914 -912.54550468 -912.61663022 ... -912.68763087
#    435.07021386  434.85695496]
#  [-309.78600073 -219.66944657 -219.72256413 ... -219.77552151
#     33.43223532   33.2733837 ]]
# adding col D5_set_pc1 to new training set
# adding col D5_set_pc1 to new test set
# adding col D5_set_pc2 to new training set
# adding col D5_set_pc2 to new test set
# calculating principal components for ['D14', 'V170', 'V182', 'V190', 'V198', 'V208', 'V217', 'V223', 'V229', 'V233', 'V237', 'V243', 'V249', 'V257', 'V269', 'V276', 'id_12', 'id_16', 'id_38']
# princial components to explain ['D14', 'V170', 'V182', 'V190', 'V198', 'V208', 'V217', 'V223', 'V229', 'V233', 'V237', 'V243', 'V249', 'V257', 'V269', 'V276', 'id_12', 'id_16', 'id_38'] have a cumulated 0.9226895392455403 explained variance ratio, to get above 0.9226895392455403 we need pcs [0]
# [[-885.29614497 -885.29614497 -885.29614497 ... -885.29614497
#   -885.29614497 -885.29614497]
#  [  23.22091717   23.22091717   23.22091717 ...   23.22091717
#     23.22091717   23.22091717]
#  [   8.92655859    8.92655859    8.92655858 ...    8.92655858
#      8.92655858    8.92655858]]
# adding col D14_set_pc1 to new training set
# adding col D14_set_pc1 to new test set
# calculating principal components for ['M2', 'dist1', 'M7', 'M9', 'V4', 'V8', 'V174', 'V186', 'V219', 'V231', 'V241', 'V253', 'id_28']
# princial components to explain ['M2', 'dist1', 'M7', 'M9', 'V4', 'V8', 'V174', 'V186', 'V219', 'V231', 'V241', 'V253', 'id_28'] have a cumulated 0.9198513195565113 explained variance ratio, to get above 0.9198513195565113 we need pcs [0, 1]
# [[  962.67244175   -67.85808258  1052.2531372  ...   622.40588594
#     957.66953444   622.40746548]
#  [  385.99854314 -1000.19794737   547.36527567 ...  -226.9479469
#     376.75138496  -226.94641006]
#  [   17.82894077   240.00821935   212.14817024 ...  -720.3032225
#       5.74752697  -720.30551482]]
# adding col M2_set_pc1 to new training set
# adding col M2_set_pc1 to new test set
# adding col M2_set_pc2 to new training set
# adding col M2_set_pc2 to new test set
# calculating principal components for ['M8', 'V2']
# princial components to explain ['M8', 'V2'] have a cumulated 0.9999984716555761 explained variance ratio, to get above 0.9999984716555761 we need pcs [0]
# [[-4.72909953e+02  5.27089317e+02 -4.72912369e+02 ... -4.72909953e+02
#   -4.72909953e+02 -4.72912369e+02]
#  [-1.24771270e+00 -3.99853695e-02  7.52285838e-01 ... -1.24771270e+00
#   -1.24771270e+00  7.52285838e-01]]
# adding col M8_set_pc1 to new training set
# adding col M8_set_pc1 to new test set
# calculating principal components for ['V10', 'V6', 'V178', 'V225', 'V247']
# princial components to explain ['V10', 'V6', 'V178', 'V225', 'V247'] have a cumulated 0.9850254173147523 explained variance ratio, to get above 0.9850254173147523 we need pcs [0, 1]
# [[-7.47697256e+02  2.40055938e+02 -7.47697256e+02 ... -7.48191236e+02
#   -7.47697256e+02 -7.48191236e+02]
#  [-2.03984496e+02  8.06353681e+02 -2.03984496e+02 ... -2.04489771e+02
#   -2.03984496e+02 -2.04489771e+02]
#  [ 5.66205784e-01 -3.89472053e+01  5.66205785e-01 ...  5.85966693e-01
#    5.66205785e-01  5.85966693e-01]]
# adding col V10_set_pc1 to new training set
# adding col V10_set_pc1 to new test set
# adding col V10_set_pc2 to new training set
# adding col V10_set_pc2 to new test set
# calculating principal components for ['V14', 'D4', 'D10', 'V12', 'V15', 'V17', 'V19', 'V21', 'V23', 'V25', 'V27', 'V29', 'V31', 'V33', 'V36', 'V40', 'V44', 'V48', 'V52', 'V54', 'V56', 'V58', 'V60', 'V62', 'V64', 'V66', 'V68', 'V70', 'V72', 'V74', 'V76', 'V78', 'V80', 'V82', 'V84', 'V86', 'V88', 'V90', 'V92', 'V94', 'V138', 'V140', 'V142', 'V144', 'V146', 'V148', 'V150', 'V152', 'V154', 'V156', 'V158', 'V161', 'V163', 'V166', 'V235', 'V267', 'V278', 'V322', 'V324', 'V326', 'V328', 'V330', 'V334', 'V336', 'V338', 'id_14', 'id_32', 'id_34']
# princial components to explain ['V14', 'D4', 'D10', 'V12', 'V15', 'V17', 'V19', 'V21', 'V23', 'V25', 'V27', 'V29', 'V31', 'V33', 'V36', 'V40', 'V44', 'V48', 'V52', 'V54', 'V56', 'V58', 'V60', 'V62', 'V64', 'V66', 'V68', 'V70', 'V72', 'V74', 'V76', 'V78', 'V80', 'V82', 'V84', 'V86', 'V88', 'V90', 'V92', 'V94', 'V138', 'V140', 'V142', 'V144', 'V146', 'V148', 'V150', 'V152', 'V154', 'V156', 'V158', 'V161', 'V163', 'V166', 'V235', 'V267', 'V278', 'V322', 'V324', 'V326', 'V328', 'V330', 'V334', 'V336', 'V338', 'id_14', 'id_32', 'id_34'] have a cumulated 0.8825301348759286 explained variance ratio, to get above 0.8825301348759286 we need pcs [0, 1, 2]
# calculating principal components for ['V24', 'D15', 'V13', 'V18', 'V22', 'V28', 'V32', 'V38', 'V46', 'V53', 'V57', 'V61', 'V65', 'V69', 'V73', 'V77', 'V81', 'V85', 'V89', 'V93', 'V139', 'V143', 'V147', 'V151', 'V155', 'V162', 'V194', 'V261', 'V323', 'V327', 'V335', 'V339', 'id_30']
# princial components to explain ['V24', 'D15', 'V13', 'V18', 'V22', 'V28', 'V32', 'V38', 'V46', 'V53', 'V57', 'V61', 'V65', 'V69', 'V73', 'V77', 'V81', 'V85', 'V89', 'V93', 'V139', 'V143', 'V147', 'V151', 'V155', 'V162', 'V194', 'V261', 'V323', 'V327', 'V335', 'V339', 'id_30'] have a cumulated 0.9017175894117541 explained variance ratio, to get above 0.9017175894117541 we need pcs [0, 1, 2]
# [[-513.92522438 -830.50758238 -896.17897706 ... -831.02649586
#   -835.58907633 -831.57481337]
#  [-997.75736982  121.3940455   169.43532038 ...  121.23968329
#    124.60213587  121.31480044]
#  [ 445.20094078 -108.37389631   15.40302377 ... -108.30388922
#    -99.66464029 -107.75849955]]
# adding col V24_set_pc1 to new training set
# adding col V24_set_pc1 to new test set
# adding col V24_set_pc2 to new training set
# adding col V24_set_pc2 to new test set
# adding col V24_set_pc3 to new training set
# adding col V24_set_pc3 to new test set
# calculating principal components for ['V55', 'V16', 'V26', 'V34', 'V50', 'V63', 'V71', 'V79', 'V87', 'V141', 'V149', 'V157', 'V325', 'V337', 'id_33']
# princial components to explain ['V55', 'V16', 'V26', 'V34', 'V50', 'V63', 'V71', 'V79', 'V87', 'V141', 'V149', 'V157', 'V325', 'V337', 'id_33'] have a cumulated 0.9019053323194218 explained variance ratio, to get above 0.9019053323194218 we need pcs [0, 1]
# [[-307.54567674 -548.85707318 -548.85707318 ... -548.85707318
#   -549.1157298  -549.1198462 ]
#  [-741.96544136  155.60812838  155.60812838 ...  155.60812838
#    155.54035137  155.78428754]
#  [ 198.22576083  -28.02394493  -28.02394493 ...  -28.02394493
#    -27.7899077   -27.79526909]]
# adding col V55_set_pc1 to new training set
# adding col V55_set_pc1 to new test set
# adding col V55_set_pc2 to new training set
# adding col V55_set_pc2 to new test set
# calculating principal components for ['V95', 'V96', 'V99', 'V101', 'V103', 'V105', 'V107', 'V109', 'V111', 'V113', 'V115', 'V117', 'V119', 'V121', 'V123', 'V125', 'V127', 'V132', 'V134', 'V164', 'V202', 'V204', 'V212', 'V279', 'V293', 'V295', 'V306', 'V308', 'V316', 'V318', 'V331', 'V333']
# princial components to explain ['V95', 'V96', 'V99', 'V101', 'V103', 'V105', 'V107', 'V109', 'V111', 'V113', 'V115', 'V117', 'V119', 'V121', 'V123', 'V125', 'V127', 'V132', 'V134', 'V164', 'V202', 'V204', 'V212', 'V279', 'V293', 'V295', 'V306', 'V308', 'V316', 'V318', 'V331', 'V333'] have a cumulated 0.9450442449675627 explained variance ratio, to get above 0.9450442449675627 we need pcs [0]
# [[-855.66714149 -903.99674139 -903.99674139 ... -903.99674139
#   -415.70994957 -643.44414535]
#  [  39.46227767    6.63952967    6.63952967 ...    6.63952967
#    286.49911314   59.7617002 ]
#  [ 289.70163665  251.71534144  251.71534144 ...  251.71534144
#    636.32575248  458.47168257]]
# adding col V95_set_pc1 to new training set
# adding col V95_set_pc1 to new test set
# calculating principal components for ['V98', 'V97', 'V102', 'V106', 'V110', 'V114', 'V118', 'V122']
# princial components to explain ['V98', 'V97', 'V102', 'V106', 'V110', 'V114', 'V118', 'V122'] have a cumulated 0.9981564295000851 explained variance ratio, to get above 0.9981564295000851 we need pcs [0, 1]
# [[-0.15109263  0.36836349  0.36836349 ...  0.36836349 -1.94728965
#   -0.39885723]
#  [-1.48376697 -2.08519474 -2.08519474 ... -2.08519474 -0.17599266
#   -1.94224139]
#  [ 0.85365457  0.25274334  0.25274334 ...  0.25274334  1.32927162
#   -0.65942893]]
# adding col V98_set_pc1 to new training set
# adding col V98_set_pc1 to new test set
# adding col V98_set_pc2 to new training set
# adding col V98_set_pc2 to new test set
# calculating principal components for ['V108', 'V100', 'V112', 'V120']
# princial components to explain ['V108', 'V100', 'V112', 'V120'] have a cumulated 0.9996798865499813 explained variance ratio, to get above 0.9996798865499813 we need pcs [0]
# [[-0.92110127 -0.92110127 -0.92110127 ... -0.92110127 -1.42098438
#   -0.92110127]
#  [-0.23393467 -0.23393467 -0.23393467 ... -0.23393467  0.63215591
#   -0.23393467]
#  [-0.00345075 -0.00345075 -0.00345075 ... -0.00345075 -0.00195571
#   -0.00345075]]
# adding col V108_set_pc1 to new training set
# adding col V108_set_pc1 to new test set
# calculating principal components for ['V126', 'V128', 'V133', 'V136', 'V165', 'V211', 'V280', 'V294', 'V307', 'V317', 'V320', 'V332']
# princial components to explain ['V126', 'V128', 'V133', 'V136', 'V165', 'V211', 'V280', 'V294', 'V307', 'V317', 'V320', 'V332'] have a cumulated 0.93061776119771 explained variance ratio, to get above 0.93061776119771 we need pcs [0]
# [[ -664.82229923  -810.56309065  -810.56309065 ...  -810.56309065
#    1819.4245098   -515.66151287]
#  [  284.85775896   191.98785437   191.98785437 ...   191.98785437
#    2233.26852155   307.30896789]
#  [   44.23759258   103.41674159   103.41674159 ...   103.41674159
#   -1528.21590247   173.52833117]]
# adding col V126_set_pc1 to new training set
# adding col V126_set_pc1 to new test set
# calculating principal components for ['V130', 'V131', 'V310', 'V312']
# princial components to explain ['V130', 'V131', 'V310', 'V312'] have a cumulated 0.9261852036203329 explained variance ratio, to get above 0.9261852036203329 we need pcs [0, 1]
# [[-1.56767795e+02 -1.56767795e+02 -1.56767795e+02 ... -1.56767795e+02
#    4.41560233e+02 -1.56767795e+02]
#  [ 1.56058087e+01  1.56058087e+01  1.56058086e+01 ...  1.56058086e+01
#   -2.64250140e+02  1.56058086e+01]
#  [ 1.34768302e-01  1.34768303e-01  1.34768303e-01 ...  1.34768303e-01
#    1.96096403e+02  1.34768303e-01]]
# adding col V130_set_pc1 to new training set
# adding col V130_set_pc1 to new test set
# adding col V130_set_pc2 to new training set
# adding col V130_set_pc2 to new test set
# calculating principal components for ['V137', 'V135', 'V319']
# princial components to explain ['V137', 'V135', 'V319'] have a cumulated 0.9745627331588678 explained variance ratio, to get above 0.9745627331588678 we need pcs [0, 1]
# [[-35.54660065 -35.54660065 -35.54660065 ... -35.54660065 -35.54660065
#   448.13377563]
#  [  2.22036925   2.22036925   2.22036925 ...   2.22036925   2.22036925
#    20.42759169]
#  [ -3.76575136  -3.76575136  -3.76575136 ...  -3.76575136  -3.76575136
#   -32.71084866]]
# adding col V137_set_pc1 to new training set
# adding col V137_set_pc1 to new test set
# adding col V137_set_pc2 to new training set
# adding col V137_set_pc2 to new test set
# calculating principal components for ['V159', 'V160']
# princial components to explain ['V159', 'V160'] have a cumulated 0.9991760117408484 explained variance ratio, to get above 0.9991760117408484 we need pcs [0]
# [[-6741.80816746 -6741.80816725 -6741.80816726 ... -6741.80816726
#   -6741.80816726 -6741.80816726]
#  [ -156.49233222  -156.49233223  -156.49233223 ...  -156.49233223
#    -156.49233223  -156.49233223]]
# adding col V159_set_pc1 to new training set
# adding col V159_set_pc1 to new test set
# calculating principal components for ['V213', 'V203', 'V298']
# princial components to explain ['V213', 'V203', 'V298'] have a cumulated 0.9674365553157418 explained variance ratio, to get above 0.9674365553157418 we need pcs [0]
# [[-6.07114786e+02 -6.07114786e+02 -6.07114786e+02 ... -6.07114786e+02
#   -6.07114786e+02 -6.07114289e+02]
#  [ 6.66864455e+01  6.66864455e+01  6.66864455e+01 ...  6.66864455e+01
#    6.66864455e+01  6.66853789e+01]
#  [-9.45316661e-02 -9.45316662e-02 -9.45316662e-02 ... -9.45316662e-02
#   -9.45316662e-02 -1.09453097e+00]]
# adding col V213_set_pc1 to new training set
# adding col V213_set_pc1 to new test set
# calculating principal components for ['V264', 'V263', 'V273']
# princial components to explain ['V264', 'V263', 'V273'] have a cumulated 0.9793546856702035 explained variance ratio, to get above 0.9793546856702035 we need pcs [0, 1]
# [[-416.28814904 -416.28814904 -416.28814904 ... -416.28814904
#   -416.28814904 -416.28814904]
#  [ 114.94436862  114.94436861  114.94436861 ...  114.94436861
#    114.94436861  114.94436861]
#  [  27.53014611   27.53014611   27.53014611 ...   27.53014611
#     27.53014611   27.53014611]]
# adding col V264_set_pc1 to new training set
# adding col V264_set_pc1 to new test set
# adding col V264_set_pc2 to new training set
# adding col V264_set_pc2 to new test set
# calculating principal components for ['V281', 'V282', 'V288', 'V296', 'V300']
# princial components to explain ['V281', 'V282', 'V288', 'V296', 'V300'] have a cumulated 0.999138754546279 explained variance ratio, to get above 0.999138754546279 we need pcs [0]
# [[-4.59422745 -4.59422745 -4.59422745 ... -4.59422745 -5.48869445
#   -5.93618819]
#  [-0.27187771 -0.27187771 -0.27187771 ... -0.27187771 -0.72818184
#    0.16870774]
#  [ 0.23968735  0.23968735  0.23968735 ...  0.23968735  0.70355338
#    0.71015248]]
# adding col V281_set_pc1 to new training set
# adding col V281_set_pc1 to new test set
# calculating principal components for ['V284', 'V285', 'V290', 'V292', 'V299', 'V302', 'V304']
# princial components to explain ['V284', 'V285', 'V290', 'V292', 'V299', 'V302', 'V304'] have a cumulated 0.942368302540666 explained variance ratio, to get above 0.942368302540666 we need pcs [0, 1]
# [[ 0.83063628  0.83063628  0.83063628 ...  0.83063628 -1.51840261
#    0.45472331]
#  [ 0.48140575  0.48140575  0.48140575 ...  0.48140575 -2.21877794
#    0.29160142]
#  [-0.7271743  -0.7271743  -0.7271743  ... -0.7271743   2.72716005
#   -0.89651003]]
# adding col V284_set_pc1 to new training set
# adding col V284_set_pc1 to new test set
# adding col V284_set_pc2 to new training set
# adding col V284_set_pc2 to new test set
# calculating principal components for ['V287', 'V286', 'V297', 'V303']
# princial components to explain ['V287', 'V286', 'V297', 'V303'] have a cumulated 0.9846865286593862 explained variance ratio, to get above 0.9846865286593862 we need pcs [0]
# [[ 0.34186459  0.34186459  0.34186459 ...  0.34186459 -0.16289542
#   -0.15810606]
#  [-0.15988631 -0.15988631 -0.15988631 ... -0.15988631  0.69096823
#   -0.36164501]
#  [-0.1442232  -0.1442232  -0.1442232  ... -0.1442232  -0.01720673
#   -0.93811717]]
# adding col V287_set_pc1 to new training set
# adding col V287_set_pc1 to new test set
# calculating principal components for ['V301', 'V283']
# princial components to explain ['V301', 'V283'] have a cumulated 0.9997406929256535 explained variance ratio, to get above 0.9997406929256535 we need pcs [0]
# [[-3.00706676 -3.00706676 -3.00706676 ... -3.00706676 -7.2528495
#   -4.42127993]
#  [ 0.04225283  0.04225283  0.04225283 ...  0.04225283  4.28174914
#    0.04120509]]
# adding col V301_set_pc1 to new training set
# adding col V301_set_pc1 to new test set
# calculating principal components for ['V311', 'V129', 'V309']
# princial components to explain ['V311', 'V129', 'V309'] have a cumulated 0.9209578187268884 explained variance ratio, to get above 0.9209578187268884 we need pcs [0]
# [[-13.79060175 -13.79060175 -13.79060175 ... -13.79060175 127.65615566
#   -13.79060175]
#  [ -2.17875376  -2.17875376  -2.17875376 ...  -2.17875376  73.84243809
#    -2.17875376]
#  [  3.28699932   3.28699932   3.28699932 ...   3.28699932 -36.60777741
#     3.28699932]]
# adding col V311_set_pc1 to new training set
# adding col V311_set_pc1 to new test set
# calculating principal components for ['V329', 'D8', 'V20', 'V42', 'V67', 'V83', 'V145', 'V215', 'id_10']
# princial components to explain ['V329', 'D8', 'V20', 'V42', 'V67', 'V83', 'V145', 'V215', 'id_10'] have a cumulated 0.9000870992519595 explained variance ratio, to get above 0.9000870992519595 we need pcs [0, 1, 2]
# [[-238.56058588 -512.76503638 -512.76503638 ... -512.76503638
#   -513.34538679 -512.76503638]
#  [-370.15168142   62.77305632   62.77305632 ...   62.77305632
#     63.28960211   62.77305632]
#  [ 244.91853291  -25.0362254   -25.0362254  ...  -25.0362254
#    -25.0910747   -25.0362254 ]]
# adding col V329_set_pc1 to new training set
# adding col V329_set_pc1 to new test set
# adding col V329_set_pc2 to new training set
# adding col V329_set_pc2 to new test set
# adding col V329_set_pc3 to new training set
# adding col V329_set_pc3 to new test set

# %% [markdown]
# Successfully lowered the complexity of the dataset from 423 features to 76

# %%
print(train_df_new.shape)
print(test_df_new.shape)
# Out:
# (590540, 77)
# (506691, 76)

# %%
# write to new csv_files
train_df_new.to_csv('../data/train_data_downscaled.csv', index=False)
test_df_new.to_csv('../data/test_data_downscaled.csv', index=False)
